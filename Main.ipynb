# %%
import pandas as pd

# %%
df=pd.read_csv(r"example1.csv")

# %%
df
# Out:
#               Time Stamp  Idli  Palav  Set Dosa  Samosa  Omelette  Vada  dosa
# 0    2021-01-09 16:08:11     1      1         1       2         2     2     5
# 1    2021-01-03 16:54:02     2      1         4       3         3     3     4
# 2    2021-01-22 00:59:09     2      4         3       1         4     5     4
# 3    2021-01-04 19:15:55     2      2         3       5         5     4     2
# 4    2021-02-07 05:55:49     1      5         1       1         3     1     4
# ..                   ...   ...    ...       ...     ...       ...   ...   ...
# 194  2021-01-07 22:02:29     4      5         2       1         1     3     5
# 195  2021-01-02 01:39:55     4      1         1       4         1     5     1
# 196  2021-01-14 02:00:35     3      4         5       2         2     4     5
# 197  2021-02-02 22:04:02     5      5         4       2         2     1     1
# 198  2021-02-04 08:45:33     4      1         3       1         2     3     4
#
# [199 rows x 8 columns]

# %%
df.mean()
df.fillna(df.mean())
# Out:
#            Time Stamp  Idli  Palav  Set Dosa  Samosa  Omelette  Vada  dosa
# 0     11/5/2021 17:00     1      1         1       2         2     2     5
# 1     11/5/2021 13:41     2      1         4       3         3     3     4
# 2    10/12/2021 16:37     2      4         3       1         4     5     4
# 3    11/30/2021 14:13     2      2         3       5         5     4     2
# 4    10/27/2021 16:23     1      5         1       1         3     1     4
# ..                ...   ...    ...       ...     ...       ...   ...   ...
# 194    1/1/2021 18:46     4      5         2       1         1     3     5
# 195  11/18/2021 14:23     4      1         1       4         1     5     1
# 196   11/15/2021 1:09     3      4         5       2         2     4     5
# 197   10/21/2021 1:22     5      5         4       2         2     1     1
# 198   1/28/2021 20:44     4      1         3       1         2     3     4
#
# [199 rows x 8 columns]

# %%
mean1 = df['Idli'].mean()
mean2 = df['dosa'].mean()
mean3 = df['Palav'].mean()
mean4 = df['Set Dosa'].mean()
mean5 = df['Samosa'].mean()
mean6 = df['Omelette'].mean()
mean7 = df['Vada'].mean()
print(mean1)
print(mean2)
print(mean3,"",mean4)

mean5
# Out:
# 3.0050251256281406
# 3.1055276381909547
# 3.020100502512563  2.829145728643216
# 3.030150753768844

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Idli','dosa','Palav','Set Dosa','Samosa','Omelette','Vada']
m = [mean1,mean2,mean3,mean4,mean5,mean6,mean7]
ax.bar(langs,m)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([mean1,mean2,mean3,mean4,mean5,mean6,mean7])
mylabels =(['Idli','dosa','Palav','Set Dosa','Samosa','Omelette','Vada'])
plt.pie(y, labels = mylabels)
plt.show()

# %%
fd=pd.read_csv(r"Lunch.csv")

# %%
fd
# Out:
#           Time Stamp  Veg Biryani  Chicken Biryani  Mutton Biryani  \
# 0    6/23/2021 20:22            2                5               2
# 1     8/17/2021 5:20            1                5               1
# 2     5/13/2021 2:36            1                5               3
# 3     8/29/2021 4:26            5                5               4
# 4    2/26/2021 20:28            5                4               2
# ..               ...          ...              ...             ...
# 173    8/5/2021 3:58            5                4               1
# 174  9/26/2021 21:38            4                5               2
# 175   4/13/2021 0:16            5                4               4
# 176   9/22/2021 2:16            4                4               5
# 177  4/18/2021 13:41            4                5               3
#
#      Fish Curry  Ghee Rost  Gobi Manchurian  Paneer chili
# 0             2          5                5             3
# 1             5          1                3             1
# 2             1          1                4             1
# 3             5          2                5             5
# 4             2          4                4             2
# ..          ...        ...              ...           ...
# 173           3          1                4             3
# 174           4          5                1             2
# 175           5          3                5             3
# 176           2          4                2             1
# 177           3          3                2             3
#
# [178 rows x 8 columns]

# %%
mean8 = fd['Veg Biryani'].mean()
mean9 = fd['Chicken Biryani'].mean()
mean10 = fd['Mutton Biryani'].mean()
mean11= fd['Fish Curry'].mean()
mean12= fd['Ghee Rost'].mean()
mean13= fd['Gobi Manchurian'].mean()
mean14= fd['Paneer chili'].mean()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Veg Biryani','Chicken Biryani','Mutton Biryani','Fish Curry','Ghee Rost','Gobi Manchurian','Paneer chili']
m = [mean8,mean9,mean10,mean11,mean12,mean13,mean14]
ax.bar(langs,m)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([mean8,mean9,mean10,mean11,mean12,mean13,mean14])
mylabels =(['Veg Biryani','Chicken Biryani','Mutton Biryani','Fish Curry','Ghee Rost','Gobi Manchurian','Paneer chili'])
plt.pie(y, labels = mylabels)
plt.show()

# %%
#breakfast weekends
df['Time Stamp'] = pd.to_datetime(df['Time Stamp'])
weekends=df[df['Time Stamp'].dt.weekday > 5]
weekends
# Out:
#              Time Stamp  Idli  Palav  Set Dosa  Samosa  Omelette  Vada  dosa
# 11  2021-10-17 23:25:00     4      4         3       1         2     5     4
# 17  2021-10-31 13:48:00     4      5         5       2         5     1     5
# 18  2021-01-10 14:21:00     4      5         5       2         3     1     2
# 22  2021-12-05 18:14:00     5      1         1       3         4     1     4
# 23  2021-12-19 17:39:00     1      1         5       1         5     3     2
# 24  2021-10-10 03:08:00     3      1         2       5         1     2     3
# 27  2021-11-21 21:31:00     1      2         5       2         5     3     3
# 30  2021-01-10 06:11:00     3      2         2       4         4     4     5
# 31  2021-10-03 17:58:00     3      3         4       1         3     3     4
# 32  2021-12-05 17:45:00     5      3         2       1         4     2     4
# 39  2021-10-31 07:25:00     2      2         2       4         3     5     3
# 40  2021-02-07 03:14:00     3      1         5       2         1     2     2
# 52  2021-01-17 08:16:00     4      1         3       5         3     1     5
# 56  2021-02-07 15:49:00     2      2         4       5         3     1     3
# 57  2021-10-17 13:20:00     5      5         4       2         5     4     4
# 79  2021-12-05 12:42:00     3      3         5       5         4     5     2
# 82  2021-10-03 02:06:00     3      5         3       5         5     2     3
# 91  2021-11-28 02:15:00     1      4         5       1         4     2     5
# 92  2021-10-03 18:07:00     2      1         3       2         5     5     1
# 101 2021-12-05 22:56:00     4      4         1       5         4     4     4
# 113 2021-10-10 18:07:00     5      3         2       4         3     3     3
# 115 2021-01-31 01:13:00     5      4         5       4         2     4     5
# 134 2021-11-21 01:23:00     4      5         4       5         2     4     2
# 137 2021-02-07 01:42:00     2      3         2       3         3     1     2
# 147 2021-12-05 10:35:00     1      2         1       3         2     5     5
# 155 2021-12-19 19:40:00     3      2         4       2         1     5     2
# 160 2021-10-10 03:40:00     3      2         4       4         2     1     3
# 163 2021-10-03 22:08:00     3      3         1       3         2     5     2
# 180 2021-10-17 12:45:00     1      1         4       3         5     1     4
# 184 2021-01-17 14:17:00     2      2         3       5         4     3     5
# 190 2021-11-28 00:21:00     2      1         5       5         1     2     4
# 192 2021-10-17 20:41:00     4      3         3       3         2     4     4

# %%
wmean1 = weekends['Idli'].mean()
wmean2 = weekends['dosa'].mean()
wmean3 = weekends['Palav'].mean()
wmean4 = weekends['Set Dosa'].mean()
wmean5 = weekends['Samosa'].mean()
wmean6 = weekends['Omelette'].mean()
wmean7 = weekends['Vada'].mean()
print(wmean1)
print(wmean2)
print(wmean3,"",wmean4,"",wmean5,"",mean6)
# Out:
# 3.03125
# 3.40625
# 2.6875  3.34375  3.1875  3.0854271356783918

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Idli','dosa','Palav','Set Dosa','Samosa','Omelette','Vada']
we = [wmean1,wmean2,wmean3,wmean4,wmean5,wmean6,wmean7]
ax.bar(langs,we)
plt.show()

# %%
#breakfast weekdays
df['Time Stamp'] = pd.to_datetime(df['Time Stamp'])
weekdays=df[df['Time Stamp'].dt.weekday <= 5]
weekdays
# Out:
#              Time Stamp  Idli  Palav  Set Dosa  Samosa  Omelette  Vada  dosa
# 0   2021-11-05 17:00:00     1      1         1       2         2     2     5
# 1   2021-11-05 13:41:00     2      1         4       3         3     3     4
# 2   2021-10-12 16:37:00     2      4         3       1         4     5     4
# 3   2021-11-30 14:13:00     2      2         3       5         5     4     2
# 4   2021-10-27 16:23:00     1      5         1       1         3     1     4
# ..                  ...   ...    ...       ...     ...       ...   ...   ...
# 194 2021-01-01 18:46:00     4      5         2       1         1     3     5
# 195 2021-11-18 14:23:00     4      1         1       4         1     5     1
# 196 2021-11-15 01:09:00     3      4         5       2         2     4     5
# 197 2021-10-21 01:22:00     5      5         4       2         2     1     1
# 198 2021-01-28 20:44:00     4      1         3       1         2     3     4
#
# [167 rows x 8 columns]

# %%
wdmean1 = weekdays['Idli'].mean()
wdmean2 = weekdays['dosa'].mean()
wdmean3 = weekdays['Palav'].mean()
wdmean4 = weekdays['Set Dosa'].mean()
wdmean5 = weekdays['Samosa'].mean()
wdmean6 = weekdays['Omelette'].mean()
wdmean7 = weekdays['Vada'].mean()
print(wdmean1," ",wdmean2," ", wdmean3," ",wdmean4," ",wdmean5," ",wdmean6," ",wdmean7)
# Out:
# 3.0   3.0479041916167664   3.0838323353293413   2.730538922155689   3.0   3.065868263473054   2.808383233532934

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['Idli','dosa','Palav','Set Dosa','Samosa','Omelette','Vada']
wd = [wdmean1,wdmean2,wdmean3,wdmean4,wdmean5,wdmean6,wdmean7]
ax.bar(langs,wd)
plt.show()

# %%
#launch weekdays
fd['Time Stamp'] = pd.to_datetime(fd['Time Stamp'])
lunch_weekdays=fd[fd['Time Stamp'].dt.weekday <= 5]
lunch_weekdays
# Out:
#              Time Stamp  Veg Biryani  Chicken Biryani  Mutton Biryani  \
# 0   2021-06-23 20:22:00            2                5               2
# 1   2021-08-17 05:20:00            1                5               1
# 2   2021-05-13 02:36:00            1                5               3
# 4   2021-02-26 20:28:00            5                4               2
# 5   2021-05-20 22:59:00            2                4               5
# ..                  ...          ...              ...             ...
# 171 2021-07-20 11:37:00            3                5               5
# 172 2021-08-11 22:09:00            1                4               1
# 173 2021-08-05 03:58:00            5                4               1
# 175 2021-04-13 00:16:00            5                4               4
# 176 2021-09-22 02:16:00            4                4               5
#
#      Fish Curry  Ghee Rost  Gobi Manchurian  Paneer chili
# 0             2          5                5             3
# 1             5          1                3             1
# 2             1          1                4             1
# 4             2          4                4             2
# 5             2          1                3             2
# ..          ...        ...              ...           ...
# 171           1          5                3             5
# 172           3          5                5             3
# 173           3          1                4             3
# 175           5          3                5             3
# 176           2          4                2             1
#
# [155 rows x 8 columns]

# %%
#lunch weekends
fd['Time Stamp'] = pd.to_datetime(fd['Time Stamp'])
lunch_weekends=fd[fd['Time Stamp'].dt.weekday > 5]
lunch_weekends
# Out:
#              Time Stamp  Veg Biryani  Chicken Biryani  Mutton Biryani  \
# 3   2021-08-29 04:26:00            5                5               4
# 37  2021-05-30 10:37:00            3                3               5
# 42  2021-05-16 07:42:00            1                5               4
# 49  2021-05-23 20:22:00            3                4               2
# 52  2021-04-18 13:16:00            3                2               3
# 65  2021-05-09 11:52:00            4                5               3
# 68  2021-03-21 08:52:00            5                1               1
# 71  2021-06-27 12:35:00            3                4               5
# 73  2021-07-18 11:15:00            3                4               2
# 77  2021-05-16 22:59:00            4                2               5
# 83  2021-05-30 05:32:00            4                4               1
# 95  2021-05-23 17:18:00            4                4               4
# 96  2021-09-19 13:19:00            3                2               2
# 100 2021-02-21 18:45:00            2                3               4
# 108 2021-02-14 17:57:00            5                2               2
# 127 2021-08-08 02:36:00            5                4               1
# 130 2021-09-05 20:28:00            5                3               5
# 141 2021-04-25 20:06:00            5                5               5
# 146 2021-02-14 17:10:00            3                2               3
# 153 2021-08-08 07:04:00            2                4               4
# 165 2021-03-07 15:28:00            3                4               4
# 174 2021-09-26 21:38:00            4                5               2
# 177 2021-04-18 13:41:00            4                5               3
#
#      Fish Curry  Ghee Rost  Gobi Manchurian  Paneer chili
# 3             5          2                5             5
# 37            2          5                4             5
# 42            2          4                4             2
# 49            4          5                3             3
# 52            3          3                3             3
# 65            3          4                4             5
# 68            3          5                4             3
# 71            3          4                3             4
# 73            4          4                5             5
# 77            3          1                1             1
# 83            1          3                5             1
# 95            3          4                4             5
# 96            2          2                4             3
# 100           3          1                3             5
# 108           5          2                1             4
# 127           1          3                4             3
# 130           3          5                2             3
# 141           3          5                2             1
# 146           3          5                5             1
# 153           5          1                5             1
# 165           4          2                5             5
# 174           4          5                1             2
# 177           3          3                2             3

# %%
lwmean1 = lunch_weekends['Veg Biryani'].mean()
lwmean2 = lunch_weekends['Chicken Biryani'].mean()
lwmean3 = lunch_weekends['Mutton Biryani'].mean()
lwmean4 = lunch_weekends['Fish Curry'].mean()
lwmean5 = lunch_weekends['Ghee Rost'].mean()
lwmean6 = lunch_weekends['Gobi Manchurian'].mean()
lwmean7 = lunch_weekends['Paneer chili'].mean()
print(lwmean1," ",lwmean2," ", lwmean3," ",lwmean4," ",lwmean5," ",lwmean6," ",lwmean7)
# Out:
# 3.608695652173913   3.5652173913043477   3.217391304347826   3.130434782608696   3.391304347826087   3.4347826086956523   3.1739130434782608

# %%
lwdmean1 = lunch_weekdays['Veg Biryani'].mean()
lwdmean2 = lunch_weekdays['Chicken Biryani'].mean()
lwdmean3 = lunch_weekdays['Mutton Biryani'].mean()
lwdmean4 = lunch_weekdays['Fish Curry'].mean()
lwdmean5 = lunch_weekdays['Ghee Rost'].mean()
lwdmean6 = lunch_weekdays['Gobi Manchurian'].mean()
lwdmean7 = lunch_weekdays['Paneer chili'].mean()
print(lwdmean1," ",lwdmean2," ", lwdmean3," ",lwdmean4," ",lwdmean5," ",lwdmean6," ",lwdmean7)
# Out:
# 2.9290322580645163   3.9806451612903224   2.9548387096774196   2.858064516129032   2.8516129032258064   3.496774193548387   3.174193548387097

# %%
#breakfast function
blist1 = [wdmean1,wdmean2,wdmean3,wdmean4,wdmean5,wdmean6,wdmean7]
bwfood = ['Idli','dosa','Palav','Set Dosa','Samosa','Omelette','Vada']
blist2=  [wmean1,wmean2,wmean3,wmean4,wmean5,wmean6,wmean7]
blist3=blist1.copy()
blist1.sort()
blist4=blist2.copy()
blist2.sort()
for i in blist3:
    if i == blist1[-1]:
        bwdindex=blist3.index(i)
for i in blist4:
    if i == blist2[-1]:
        bweindex=blist4.index(i)
def determineBreakfast(weekorweekend):
    if(weekorweekend == "weekday" ):
        print("Suggested breakfast for weekday is "+ bwfood[bwdindex])
    if(weekorweekend == "weekend"):
        print("Suggested breakfast for weekend is "+ bwfood[bweindex])

#lunch function
llist1 = [lwdmean1,lwdmean2,lwdmean3,lwdmean4,lwdmean5,lwdmean6,lwdmean7]
lwfood=  ['Veg Biryani','Chicken Biryani','Mutton Biryani','Fish Curry','Ghee Rost','Gobi Manchurian','Paneer chili']
llist2=  [lwmean1,lwmean2,lwmean3,lwmean4,lwmean5,lwmean6,lwmean7]
llist3=llist1.copy()
llist1.sort()
llist4=llist2.copy()
llist2.sort()
for i in llist3:
    if i == llist1[-1]:
        lwdindex=llist3.index(i)
for i in llist4:
    if i == llist2[-1]:
        lweindex=llist4.index(i)
def determineLunch(weekorweekend):
    if(weekorweekend == "weekday" ):
        print("Suggested Lunch for weekday is "+ lwfood[lwdindex])
    if(weekorweekend == "weekend"):
        print("Suggested Lunch for weekend is "+ lwfood[lweindex])
        
determineBreakfast("weekend")
determineBreakfast("weekday")
determineLunch("weekend")
determineLunch("weekday")
# Out:
# Suggested breakfast for weekend is dosa
# Suggested breakfast for weekday is Palav
# Suggested Lunch for weekend is Veg Biryani
# Suggested Lunch for weekday is Chicken Biryani
